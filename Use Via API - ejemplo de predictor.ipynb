# %% [markdown]
# # Librería a instalar

# %%
#1. Install the python client (docs) if you don't already have it installed
#!pip install gradio_client
# Out:
# Requirement already satisfied: gradio_client in /usr/local/lib/python3.12/dist-packages (1.13.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from gradio_client) (2025.3.0)
# Requirement already satisfied: httpx>=0.24.1 in /usr/local/lib/python3.12/dist-packages (from gradio_client) (0.28.1)
# Requirement already satisfied: huggingface-hub<2.0,>=0.19.3 in /usr/local/lib/python3.12/dist-packages (from gradio_client) (0.36.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from gradio_client) (25.0)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.12/dist-packages (from gradio_client) (4.15.0)
# Requirement already satisfied: websockets<16.0,>=13.0 in /usr/local/lib/python3.12/dist-packages (from gradio_client) (15.0.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx>=0.24.1->gradio_client) (4.11.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx>=0.24.1->gradio_client) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.24.1->gradio_client) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx>=0.24.1->gradio_client) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.24.1->gradio_client) (0.16.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.19.3->gradio_client) (3.20.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.19.3->gradio_client) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.19.3->gradio_client) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.19.3->gradio_client) (4.67.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.19.3->gradio_client) (1.2.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx>=0.24.1->gradio_client) (1.3.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub<2.0,>=0.19.3->gradio_client) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub<2.0,>=0.19.3->gradio_client) (2.5.0)

# %% [markdown]
# ## Código para validar el endpoint (API)

# %% [markdown]
# En APP.PY en demo.launch agregar (share=True) para crear el túnel.
# Tiene que estar desactivado el firewall y el antivirus.
#     demo.launch(share=True)

# %% [markdown]
# # Prueba 1 con parametros de Default

# %%
#2. Find the API endpoint below corresponding to your desired function in the app. Copy the code snippet, replacing the placeholder values with your own input data. Or use the
#API Recorder to automatically generate your API requests.
from gradio_client import Client

client = Client("https://3738a56d61cc05b5c3.gradio.live/")
result = client.predict(
		param_0=60,
		param_1=50,
		param_2=2,
		param_3=1,
		param_4=1,
		param_5="Casa",
		param_6="Capital Federal",
		param_7="Palermo",
		api_name="/predict_price"
)
print(result)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Loaded as API: https://3738a56d61cc05b5c3.gradio.live/ ✔
#
# <div style="
#     background:#E9FFF8;
#     border:1px solid #B6F3E2;
#     border-radius:16px;
#     padding:24px;
#     text-align:center;
#     box-shadow: 0 6px 18px rgba(10, 92, 79, 0.10);
# ">
#   <div style="font-size:14px;color:#0A5C4F;opacity:0.85;margin-bottom:8px;">
#     Precio estimado (ARS)
#   </div>
#   <div style="font-size:40px;font-weight:800;color:#0A5C4F;letter-spacing:0.5px;">
#     $ 187.194,43
#   </div>
#   <div style="font-size:12px;color:#0A5C4F;opacity:0.7;margin-top:10px;">
#     Estimación basada en los datos ingresados.
#   </div>
# </div>

# %% [markdown]
# Valor de predicción según Gradio para casa en Palermo: $ 187.194,43

# %% [markdown]
# # Prueba 2 - Modifico algunos parámetros
# *   Sup Total
# *   Tipo de Propiedad
# *   Barrio

# %%
# Segunda consulta - modifico parametros
from gradio_client import Client

client = Client("https://3738a56d61cc05b5c3.gradio.live/")
result = client.predict(
		param_0=50,
		param_1=50,
		param_2=2,
		param_3=1,
		param_4=1,
		param_5="Departamento",
		param_6="Capital Federal",
		param_7="Caballito",
		api_name="/predict_price"
)
print(result)
# Out:
# Loaded as API: https://3738a56d61cc05b5c3.gradio.live/ ✔
#
# <div style="
#     background:#E9FFF8;
#     border:1px solid #B6F3E2;
#     border-radius:16px;
#     padding:24px;
#     text-align:center;
#     box-shadow: 0 6px 18px rgba(10, 92, 79, 0.10);
# ">
#   <div style="font-size:14px;color:#0A5C4F;opacity:0.85;margin-bottom:8px;">
#     Precio estimado (ARS)
#   </div>
#   <div style="font-size:40px;font-weight:800;color:#0A5C4F;letter-spacing:0.5px;">
#     $ 149.031,91
#   </div>
#   <div style="font-size:12px;color:#0A5C4F;opacity:0.7;margin-top:10px;">
#     Estimación basada en los datos ingresados.
#   </div>
# </div>

# %% [markdown]
# Valor de predicción según Gradio para departamento en CABA: $ 149.031,91

# %% [markdown]
# # Default de parametros

# %% [markdown]
# Accepts 8 parameters:
# param_0 float Default: 60
#
# The input value that is provided in the "Superficie total (m²)" Number component.
#
# param_1 float Default: 50
#
# The input value that is provided in the "Superficie cubierta (m²)" Number component.
#
# param_2 float Default: 2
#
# The input value that is provided in the "Ambientes" Slider component.
#
# param_3 float Default: 1
#
# The input value that is provided in the "Dormitorios" Slider component.
#
# param_4 float Default: 1
#
# The input value that is provided in the "Baños" Slider component.
#
# param_5 Literal['Casa', 'Casa de campo', 'Cochera', 'Departamento', 'Depósito', 'Local comercial', 'Lote', 'Oficin

# %% [markdown]
# The input value that is provided in the "Tipo de propiedad" Dropdown component.
#
# param_6 Literal['Bs.As. G.B.A. Zona Norte', 'Bs.As. G.B.A. Zona Oeste', 'Bs.As. G.B.A. Zona Sur', 'Capital Federal'] Default: "Capi

# %% [markdown]
# The input value that is provided in the "Zona/Provincia" Dropdown component.
#
# param_7 Literal['Palermo', 'Quilmes', 'Lomas de Zamora', 'Morón', 'Belgrano', 'Lanús', 'Caballito', 'Ituzaingó', 'Vicente Lópe

# %% [markdown]
# Returns 1 element
# str
#
# The output value that appears in the "value_16" Html component.

# %% [markdown]
# Si no hago el tunel, puedo correrlo de manera local desde Visual Code
#  API documentation http://127.0.0.1:7860/
